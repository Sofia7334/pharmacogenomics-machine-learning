# %%
import pandas as pd

clinical = pd.read_csv("../data/raw/clinicalVariants.tsv", sep="\t")
drug = pd.read_csv("../data/raw/var_drug_ann.tsv", sep="\t")
functional = pd.read_csv("../data/raw/var_fa_ann.tsv", sep="\t")
phenotypes = pd.read_csv("../data/raw/var_pheno_ann.tsv", sep="\t")

clinical.head()
# drug.head()
# functional.head()
# phenotypes.head()
# Out:
#                            variant     gene           type level of evidence  \
# 0    CYP2C9*1, CYP2C9*3, CYP2C9*13   CYP2C9  Metabolism/PK                1A
# 1                       rs17376848     DPYD       Toxicity                1A
# 2                        rs2297595     DPYD       Toxicity                1A
# 3                        rs1801265     DPYD       Toxicity                1A
# 4  CYP2C19*1, CYP2C19*2, CYP2C19*3  CYP2C19  Metabolism/PK                1A
#
#          chemicals phenotypes
# 0       lornoxicam        NaN
# 1     capecitabine  Neoplasms
# 2     capecitabine  Neoplasms
# 3     capecitabine  Neoplasms
# 4  dexlansoprazole        NaN

# %% [markdown]
# In clinicalVariants.tsv it seems that some variants are labeled based on the haplotype-based star(*) system while others use reference SNP cluster IDs (rdIDs) to avoid legacy structural conflicts. This will likely be an issue if passed directly into the machine learning pipeline, so it must be addressed.
